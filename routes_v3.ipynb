# %% [markdown]
# ## READ ME
# Estos son los detalles de lo que hace el código:
# 1. importar librerías
# 2. importar data y realizar limpieza
#
#     a. eliminar nulos (no afecta a las reservas)
#
#     b. rellena los valores que tienen hora de reserva en blanco con el valor que se encuentra arriba
# 3. verificar las direcciones correctas. Las que no estén verificadas se proceden a dejar fuera para que posteriormente se modifiquen manualmente
# 4. Se calcula la distancia entre cada par de direcciones usando coordenadas (origen y destino)

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.distance import great_circle
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage ,fcluster
import googlemaps
import re
import time
import requests
import pickle
import os



import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'C:\Users\martin.olivares\Desktop\projects\best-route\data\test_6.csv')

df=pd.DataFrame()
df['address']=data['Direccion de inicio']
df['hora_recogida']=data['Hora de recogida']
df['destino']=data['Dirección destino']

df["num_empty_cells"] = df.isna().sum(axis=1)
df["nulls"]=df['num_empty_cells']/max(df['num_empty_cells'])

df = df.drop(df[df['nulls']==1].index)
df.fillna(method='ffill', inplace=True)

df.drop(columns=['nulls','num_empty_cells'],inplace=True)

# %%
# Definir un diccionario con las abreviaturas de calles y sus correspondientes formas completas
street_abbreviations = {
    "cl": "calle",
    "av": "avenida",
    "pj": "pasaje",
    "cam": "camino",
    "nte": "norte",
    "hermnos":'hnos',
    'hmnos':'hermanos',
    'tte':'teniente',
    'concon':'con con'
    }


# Definir una función que corrija las abreviaturas de calles en una dirección
def correct_typos(address):
    for abbreviation, full_form in street_abbreviations.items():
        address = re.sub(r'\b{}\b'.format(abbreviation), full_form, address)
    return address

# Aplicar la función a cada dirección del DataFrame
df["address"] = df["address"].str.lower().apply(correct_typos)
df['destino'] = df["destino"].str.lower().apply(correct_typos)

# %%
clave_api='AIzaSyAvTzCycvOetN-NA51GNqxb80d-Ma-0Azg'

googlemaps_cache = 'googlemaps_cache.pkl'

def load_cache():
    # Cargar la caché desde el archivo si existe
    if os.path.exists(googlemaps_cache):
        with open(googlemaps_cache, 'rb') as f:
            return pickle.load(f)
    else:
        return {}

def save_cache(cache):
    # Guardar la caché en el archivo
    with open(googlemaps_cache, 'wb') as f:
        pickle.dump(cache, f)

def correct_address(direccion):
    # Cargar la caché desde el archivo
    cache = load_cache()
    # Verificar si el resultado de la dirección ya está en la caché
    if direccion in cache:
        return cache[direccion]
    # Si el resultado de la dirección no está en la caché, realizar una solicitud a la API de Google Maps
    gmaps = googlemaps.Client(key=clave_api)
    geocode_result = gmaps.geocode(direccion)
    if len(geocode_result) > 0:
        formatted_address = geocode_result[0]['formatted_address']
        # Agregar el resultado a la caché para futuras solicitudes
        cache[direccion] = formatted_address
        save_cache(cache)
        return formatted_address
    else:
        return np.nan

# %%
df['address'] = df['address'].apply(correct_address)
df['destino'] = df['destino'].apply(correct_address)
df['aux'] = df.groupby(['address', 'hora_recogida'])['address'].transform(lambda x: x.duplicated(keep=False)).astype(bool)

print('Numero de valores erroneos:')
print(df.isna().sum())
print('-----------------------------------')
print('Lista errores:')
df[df.isna().any(axis=1)]
# Out:
# Numero de valores erroneos:
# address          0
# hora_recogida    0
# destino          0
# aux              0
# dtype: int64
# -----------------------------------
# Lista errores:
# Empty DataFrame
# Columns: [address, hora_recogida, destino, aux]
# Index: []

# %%
df.dropna(inplace=True)



# Creamos un cliente de Google Maps con nuestra clave API
gmaps = googlemaps.Client(key=clave_api)

# Comprobamos si el archivo existe y no está vacío antes de cargar la memoria caché
if os.path.exists("coordinates_googlemaps.pkl") and os.path.getsize("geocode_cache.pickle") > 0:
    with open("coordinates_googlemaps.pkl", "rb") as f:
        geocode_cache = pickle.load(f)
else:
    geocode_cache = {}

# Creamos una función para guardar la memoria caché en un archivo externo
def save_geocode_cache():
    with open("coordinates_googlemaps.pkl", "wb") as f:
        pickle.dump(geocode_cache, f)

# Creamos una función para geolocalizar una dirección y almacenar las coordenadas en la caché
def geolocate(address):
    if address in geocode_cache:
        return geocode_cache[address]
    else:
        geocode_result = gmaps.geocode(address)
        if len(geocode_result) > 0:
            location = geocode_result[0]['geometry']['location']
            coordinates = (location['lat'], location['lng'])
            geocode_cache[address] = coordinates
            save_geocode_cache()  # Guardamos la memoria caché en un archivo externo
            return coordinates
        else:
            return None

# %%
false_df = df[df['aux']==False]
false_grouped = false_df.groupby("hora_recogida")

true_df = df[df['aux']==True]
true_grouped = true_df.groupby("hora_recogida")

# %% [markdown]
# start_time = time.time()
#
#
# for name, group in false_grouped:
#     # Calcula la distancia entre cada par de direcciones
#     X = np.zeros((len(group), len(group)))
#     for i in range(len(group)):
#         address1 = group.iloc[i]['address']
#         loc1 = geolocate(address1)  # Utilizamos nuestra función personalizada para geolocalizar la dirección
#         if loc1 is not None:
#             lat1, lon1 = loc1
#             point1 = (lat1, lon1)
#             for j in range(i+1, len(group)):
#                 address2 = group.iloc[j]['address']
#                 loc2 = geolocate(address2)  # Utilizamos nuestra función personalizada para geolocalizar la dirección
#                 if loc2 is not None:
#                     lat2, lon2 = loc2
#                     point2 = (lat2, lon2)
#                     X[i, j] = great_circle(point1, point2).m
#                     X[j, i] = great_circle(point1, point2).m
#     # Crea una matriz con las distancias
#     kmeans = KMeans(n_clusters=1)
#     kmeans.fit(X)
#     group['label'] = kmeans.labels_
#     # Continúa agrupando hasta que cada clúster tenga 4 o menos direcciones
#     while group.groupby('label').agg({'address':'count'}).max().values[0] > 4 and kmeans.n_clusters < len(group):
#         kmeans.n_clusters += 1
#         kmeans.fit(X)
#         group['label'] = kmeans.labels_
#     false_df.loc[group.index, "label"] = group["label"]
#
# end_time = time.time()
#
# print("Tiempo de ejecución del primer bloque de código: %.2f segundos" % (end_time - start_time))
# # busca la ruta mas optima, entonces, no maximiza los vehiculos
# # que todos se maximicen, y solamente existiría un vehiculo (ultimos valores) que podría tener menos
#
# false_df.columns

# %%
start_time = time.time()


for name, group in true_grouped:
    # Calcula la distancia entre cada par de direcciones
    X = np.zeros((len(group), len(group)))
    for i in range(len(group)):
        address1 = group.iloc[i]['destino']
        loc1 = geolocate(address1)  # Utilizamos nuestra función personalizada para geolocalizar la dirección
        if loc1 is not None:
            lat1, lon1 = loc1
            point1 = (lat1, lon1)
            for j in range(i+1, len(group)):
                address2 = group.iloc[j]['destino']
                loc2 = geolocate(address2)  # Utilizamos nuestra función personalizada para geolocalizar la dirección
                if loc2 is not None:
                    lat2, lon2 = loc2
                    point2 = (lat2, lon2)
                    X[i, j] = great_circle(point1, point2).m
                    X[j, i] = great_circle(point1, point2).m
    # Crea una matriz con las distancias
    kmeans = KMeans(n_clusters=1)
    kmeans.fit(X)
    group['label'] = kmeans.labels_
    
    labels = np.zeros(len(group))
    cluster_label = 1
    for i in range(len(group)):
        if labels[i] == 0:
            labels[i] = cluster_label
            for j in range(i+1, len(group)):
                if labels[j] == 0 and np.sum(labels == cluster_label) < 8 and X[i, j] > 0:
                    labels[j] = cluster_label
            cluster_label += 1
            
    group['label'] = labels
    true_df.loc[group.index, "label"] = group["label"]



end_time = time.time()
print("Tiempo de ejecución del segundo bloque de código: %.2f segundos" % (end_time - start_time))
# Out:
# Tiempo de ejecución del segundo bloque de código: 0.30 segundos

# %%
true_df
# Out:
#                                               address hora_recogida  \
# 0   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 1   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 2   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 3   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 4   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 5   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 6   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 7   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 8   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 9   Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 10  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 11  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 12  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 13  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 14  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 15  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 16  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 17  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 18  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 19  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 20  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 21  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 22  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 23  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 24  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 25  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 26  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 27  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 28  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 29  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 30  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 31  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 32  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 33  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 34  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 35  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
# 36  Guanaco Nte. 4819, Huechuraba, Región Metropol...          1:45
#
#                                               destino   aux  label
# 0   Av. Mapocho 4643, 8500093 Quinta Normal, Regió...  True    1.0
# 1   Zapallar 2444, Conchalí, Región Metropolitana,...  True    1.0
# 2   Valdivia 2347, 8520803 Quinta Normal, Región M...  True    1.0
# 3    Dos Sur 3881, Renca, Región Metropolitana, Chile  True    1.0
# 4   Alsino 4820, Quinta Normal, Región Metropolita...  True    1.0
# 5   Poeta Pedro Prado 1681, depto 341, Quinta Norm...  True    1.0
# 6   Mapocho Nte. 8151, 9090967 Santiago, Cerro Nav...  True    1.0
# 7   Francisco Errázuriz 1364, Renca, Santiago, Reg...  True    1.0
# 8   Quillay Pte. 2474, Lampa, Región Metropolitana...  True    2.0
# 9   Eleuterio Ramírez 40, Lampa, Región Metropolit...  True    2.0
# 10  Parroquia Jesús Obrero 685, 1420000 Quilicura,...  True    2.0
# 11  C. la Finca 952, Lampa, Región Metropolitana, ...  True    2.0
# 12  Lo Marcoleta 503, Quilicura, Región Metropolit...  True    2.0
# 13  Diag. Reny 1616, 9090799 Santiago, Cerro Navia...  True    2.0
# 14  Av. Flor de Lis 1735, Renca, Región Metropolit...  True    2.0
# 15  Ipe Amarillo 8035, 8661406 Santiago, Renca, Re...  True    2.0
# 16  Alberto Risopatrón 1567, 8700071 Santiago, Qui...  True    3.0
# 17  Limarí 1572, 8700439 Santiago, Quilicura, Regi...  True    3.0
# 18  Sarago Nte. 538, Quilicura, Región Metropolita...  True    3.0
# 19  Piedra Roja 113, Quilicura, Región Metropolita...  True    3.0
# 20  Piedra Roja 1112, Quilicura, Región Metropolit...  True    3.0
# 21  Los Himalayas 0156, Quilicura, Región Metropol...  True    3.0
# 22  De La Luna 205, Quilicura, Región Metropolitan...  True    3.0
# 23  Ana Mangiamarchi 574, Quilicura, Santiago, Reg...  True    3.0
# 24  Av - La Montaña Nte. 3650, Lampa, Región Metro...  True    4.0
# 25  Río Maule 2750, Valle Grande, Lampa, Región Me...  True    4.0
# 26  Blanca Estela Sur 4053, 9391558 Chacabuco, Lam...  True    4.0
# 27  La Luz, Valle Grande, Lampa, Región Metropolit...  True    4.0
# 28  Río Maule 3018, Valle Grande, Lampa, Región Me...  True    4.0
# 29  santa teresita de lisieux, Lo Solar, Lampa, Re...  True    4.0
# 30  Río Loa 773, Valle Grande, Lampa, Región Metro...  True    4.0
# 31  Sta. Isidora 1420, Quilicura, Región Metropoli...  True    4.0
# 32  Los Dakotas 1174, Quilicura, Región Metropolit...  True    5.0
# 33  Oruro 0476, Quilicura, Región Metropolitana, C...  True    5.0
# 34  La Fuente 474, Quilicura, Región Metropolitana...  True    5.0
# 35  Trinidad 640, La Florida, Región Metropolitana...  True    5.0
# 36  Madreselvas 3020, Macul, Región Metropolitana,...  True    5.0

# %%
df=pd.concat([false_df,true_df])

df=df[['hora_recogida','address','destino','label']]
df.sort_values(by=['hora_recogida'])

df
# Out:
#    hora_recogida                                            address  \
# 0           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 1           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 2           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 3           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 4           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 5           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 6           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 7           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 8           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 9           1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 10          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 11          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 12          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 13          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 14          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 15          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 16          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 17          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 18          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 19          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 20          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 21          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 22          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 23          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 24          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 25          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 26          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 27          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 28          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 29          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 30          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 31          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 32          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 33          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 34          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 35          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
# 36          1:45  Guanaco Nte. 4819, Huechuraba, Región Metropol...
#
#                                               destino  label
# 0   Av. Mapocho 4643, 8500093 Quinta Normal, Regió...    1.0
# 1   Zapallar 2444, Conchalí, Región Metropolitana,...    1.0
# 2   Valdivia 2347, 8520803 Quinta Normal, Región M...    1.0
# 3    Dos Sur 3881, Renca, Región Metropolitana, Chile    1.0
# 4   Alsino 4820, Quinta Normal, Región Metropolita...    1.0
# 5   Poeta Pedro Prado 1681, depto 341, Quinta Norm...    1.0
# 6   Mapocho Nte. 8151, 9090967 Santiago, Cerro Nav...    1.0
# 7   Francisco Errázuriz 1364, Renca, Santiago, Reg...    1.0
# 8   Quillay Pte. 2474, Lampa, Región Metropolitana...    2.0
# 9   Eleuterio Ramírez 40, Lampa, Región Metropolit...    2.0
# 10  Parroquia Jesús Obrero 685, 1420000 Quilicura,...    2.0
# 11  C. la Finca 952, Lampa, Región Metropolitana, ...    2.0
# 12  Lo Marcoleta 503, Quilicura, Región Metropolit...    2.0
# 13  Diag. Reny 1616, 9090799 Santiago, Cerro Navia...    2.0
# 14  Av. Flor de Lis 1735, Renca, Región Metropolit...    2.0
# 15  Ipe Amarillo 8035, 8661406 Santiago, Renca, Re...    2.0
# 16  Alberto Risopatrón 1567, 8700071 Santiago, Qui...    3.0
# 17  Limarí 1572, 8700439 Santiago, Quilicura, Regi...    3.0
# 18  Sarago Nte. 538, Quilicura, Región Metropolita...    3.0
# 19  Piedra Roja 113, Quilicura, Región Metropolita...    3.0
# 20  Piedra Roja 1112, Quilicura, Región Metropolit...    3.0
# 21  Los Himalayas 0156, Quilicura, Región Metropol...    3.0
# 22  De La Luna 205, Quilicura, Región Metropolitan...    3.0
# 23  Ana Mangiamarchi 574, Quilicura, Santiago, Reg...    3.0
# 24  Av - La Montaña Nte. 3650, Lampa, Región Metro...    4.0
# 25  Río Maule 2750, Valle Grande, Lampa, Región Me...    4.0
# 26  Blanca Estela Sur 4053, 9391558 Chacabuco, Lam...    4.0
# 27  La Luz, Valle Grande, Lampa, Región Metropolit...    4.0
# 28  Río Maule 3018, Valle Grande, Lampa, Región Me...    4.0
# 29  santa teresita de lisieux, Lo Solar, Lampa, Re...    4.0
# 30  Río Loa 773, Valle Grande, Lampa, Región Metro...    4.0
# 31  Sta. Isidora 1420, Quilicura, Región Metropoli...    4.0
# 32  Los Dakotas 1174, Quilicura, Región Metropolit...    5.0
# 33  Oruro 0476, Quilicura, Región Metropolitana, C...    5.0
# 34  La Fuente 474, Quilicura, Región Metropolitana...    5.0
# 35  Trinidad 640, La Florida, Región Metropolitana...    5.0
# 36  Madreselvas 3020, Macul, Región Metropolitana,...    5.0

# %%
import gmaps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Carga tus datos en un dataframe
df = true_df

# Agrupa los datos por etiqueta de cluster
groups = df.groupby('label')

# Crea una paleta de colores para los clusters utilizando matplotlib
colors = plt.cm.tab20(np.linspace(0, 1, len(groups)))
color_dict = {}
for i, label in enumerate(groups.groups):
    color_dict[label] = tuple(colors[i, :3])

# Crea una lista de ubicaciones (latitud, longitud) para cada dirección en tus datos
locations = []
for i, row in df.iterrows():
    address = row['destino']
    loc = geolocate(address)
    if loc is not None:
        lat, lng = loc
        locations.append((lat, lng))

# Crea una capa de marcadores para cada cluster
markers = []
for label, group in groups:
    color = color_dict[label]
    group_locs = [locations[i] for i in group.index.tolist()]
    marker_list = []
    for i, loc in enumerate(group_locs):
        info_box_content = group.iloc[i]['destino']
        marker = gmaps.Marker(location=loc, label=str(label), title=info_box_content, 
                              info_box=gmaps.InfoBox(content=info_box_content))
        marker_list.append(marker)
    marker_layer = gmaps.Markers(markers=marker_list, stroke_color=color, fill_color=color)
    markers.append(marker_layer)

# Crea un mapa y agrega las capas de marcadores
fig = gmaps.figure(center=(40, -98), zoom_level=4)
for marker in markers:
    fig.add_layer(marker)

# Muestra el mapa
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 36
#      33 for i, loc in enumerate(group_locs):
#      34     info_box_content = group.iloc[i]['destino']
#      35     marker = gmaps.Marker(location=loc, label=str(label), title=info_box_content,
# ---> 36                           info_box=gmaps.InfoBox(content=info_box_content))
#      37     marker_list.append(marker)
#      38 marker_layer = gmaps.Markers(markers=marker_list, stroke_color=color, fill_color=color)
#
# AttributeError: module 'gmaps' has no attribute 'InfoBox'
